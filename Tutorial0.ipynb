# %%
1+2
# Out:
# 3

# %%
x = 34 - 23

# %%
y = "Hello"

# %%
z = 3.45

# %%
if z == 3.45 or y == "Hello":
  x = x + 1
  y = y + "World"

# %%
print (x)
# Out:
# 12

# %%
print (y)
# Out:
# HelloWorld

# %%
z = 5 / 2

# %%
print (z)
# Out:
# 2.5

# %%
x = 3.456

# %%
x, y = 2, 3

# %%
print (x, y)
# Out:
# 2 3

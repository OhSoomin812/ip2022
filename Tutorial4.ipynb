# %%
x == y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9cfbd892cdaa> in <module>
# ----> 1 x == y
#
# NameError: name 'x' is not defined

# %%
x is y:

# %%
a and b

# %%
a or b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-51429399a6cf> in <module>
# ----> 1 a or b
#
# NameError: name 'a' is not defined

# %%
not a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-666acecd4e9c> in <module>
# ----> 1 not a
#
# NameError: name 'a' is not defined

# %%
x = true_value if conditon else false_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4bb0086f4e0b> in <module>
# ----> 1 x = true_value if conditon else false_value
#
# NameError: name 'conditon' is not defined

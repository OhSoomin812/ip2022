# %%
for (x, y) in [(a,1), (b,2), (c,3), (d,4)]:
  print (x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8b4e780b1fc> in <module>
# ----> 1 for (x, y) in [(a,1), (b,2), (c,3), (d,4)]:
#       2   print (X)
#
# NameError: name 'a' is not defined

# %%
for x in range(5) :
  print (x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(len(mylist)):
    print (i, mylist[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8da7641dbb9a> in <module>
# ----> 1 for i in range(len(mylist)):
#       2     print (i, mylist[i])
#
# NameError: name 'mylist' is not defined

# %%
for (i, item) in enumerate(mylist) :
    print (i, item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3dfc9b88f191> in <module>
# ----> 1 for (i, item) in enumerate(mylist) :
#       2     print (i, item)
#
# NameError: name 'mylist' is not defined
